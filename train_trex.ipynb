# %%
# !pip install matplotlib

# %%
from mss import mss
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

with mss() as sct:
    monitor = sct.monitors[1]
    image = np.array(sct.grab(monitor))[:,:,:3]

    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    plt.imshow(gray_image)
    plt.show()

    dino_template = cv2.imread(os.path.join('templates', 'dino.png'), 0)
    res = cv2.matchTemplate(gray_image, dino_template, cv2.TM_CCOEFF_NORMED)
    print(res)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-f0a0c63aabf5> in <module>
#      14
#      15     dino_template = cv2.imread(os.path.join('templates', 'dino.png'), 0)
# ---> 16     res = cv2.matchTemplate(gray_image, dino_template, cv2.TM_CCOEFF_NORMED)
#      17     print(res)
#
# error: OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\imgproc\src\templmatch.cpp:588: error: (-215:Assertion failed) corr.rows <= img.rows + templ.rows - 1 && corr.cols <= img.cols + templ.cols - 1 in function 'cv::crossCorr'
